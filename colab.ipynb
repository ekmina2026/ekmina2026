# %% [markdown]
# <a href="https://colab.research.google.com/github/ekmina2026/ekmina2026/blob/main/colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# Using force_remount=True to reset the connection attempt
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os

#for file in os.walk("."):
 # if 'EKMINA' in str(file):
   # print(file)
with open("./drive/Shareddrives/EKMINA2026/colab/test.txt","r") as f:
  print(f.readline())
# Out:
# hello

# %%
nowy kod
